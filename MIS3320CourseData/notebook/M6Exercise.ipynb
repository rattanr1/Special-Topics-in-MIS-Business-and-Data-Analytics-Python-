# %%
#import pandas library and introduce numpy missing values
import pandas as pd
from numpy import NaN, NAN, nan

# %%
#These codes examine whether NaN is equivalent to True, False, 0, or empty string

# %%
NaN == True
# Out:
# False

# %%
NaN == False
# Out:
# False

# %%
NaN == 0
# Out:
# False

# %%
NaN == ''
# Out:
# False

# %%
pd.isnull (NaN)
# Out:
# True

# %%
pd.isnull (18)
# Out:
# False

# %%
pd.notnull (NaN)
# Out:
# False

# %%
pd.notnull(18)
# Out:
# True

# %%
#showing data type for the reading column

# %%
#load and show the visited data set. In some data sets, missing values are represented as  ' . '
visited = pd.read_csv('..\data\survey_visited_missing.csv')
visited
# Out:
#    ident   site    dated reading
# 0    619   DR-1   2/8/27    9.82
# 1    622   DR-1  2/10/27    3.78
# 2    734   DR-3   1/7/39    1.45
# 3    735   DR-3  1/12/30    1.67
# 4    751   DR-3  2/26/30    5.51
# 5    752   DR-3        .       .
# 6    837  MSK-4  1/14/32       .
# 7    844   DR-1  3/22/32    22.5

# %%
#show the column data t’types. Note the data types for reading is incorrect (object for numbers?)
visited.dtypes
# Out:
# ident       int64
# site       object
# dated      object
# reading    object
# dtype: object

# %%
#What should the data type for reading be (if null values are specified correctly)? Why?

#Float Numbers so that pandas can perform calculation; Numeric data types include integers and floats. 

#A floating point (known as a float) number has decimal points even if that decimal point value is 0. 

#For example: 1.13, 2.0, 1234.345.

# %%
import pandas as pd

# %%
#load and show the visited data set, with specifying the msising values.
visited = pd.read_csv('..\data\survey_visited_missing.csv', na_values=['.'])
visited
# Out:
#    ident   site    dated  reading
# 0    619   DR-1   2/8/27     9.82
# 1    622   DR-1  2/10/27     3.78
# 2    734   DR-3   1/7/39     1.45
# 3    735   DR-3  1/12/30     1.67
# 4    751   DR-3  2/26/30     5.51
# 5    752   DR-3      NaN      NaN
# 6    837  MSK-4  1/14/32      NaN
# 7    844   DR-1  3/22/32    22.50

# %%
#show the column data t’types. 
visited.dtypes
# Out:
# ident        int64
# site        object
# dated       object
# reading    float64
# dtype: object

# %%
#import ebola data set
ebola = pd.read_csv('..\data\country_timeseries.csv')
ebola.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# ...

# %%
# missing values coded as NaN (no value)

# %%
#recode missing values to -99
ebola_recode = ebola.fillna (-99)
ebola_recode.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0          -99.0            10030.0
# 1    1/4/2015  288        2775.0          -99.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286         -99.0         8157.0              -99.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0          -99.0             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0          -99.0             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0          -99.0          -99.0               -99.0        -99.0       -99.0
# ...

# %%
ebola.count()
#will count how many values
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
#count missing value
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count()
num_missing
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
#import ebola data set
ebola = pd.read_csv('..\data\country_timeseries.csv')
ebola.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# ...

# %%
#interpolate (fill or insert) missing value using existing data (use with caution!)
ebola_interpolate = ebola.interpolate()
ebola_interpolate.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2749.5         8157.0             9677.5
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0         7997.5             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0         7919.5             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# ...

# %%
#Interpolation uses existing values to fill in missing values. This can compromise the accuracy of data if not used correctly.

# %%
#If any NA values are present, drop that row.
ebola_drop=ebola.dropna()
ebola_drop.shape
# Out:
# (1, 18)

# %%
#only row 19, thus not a good idea to drop
ebola_drop.shape
# Out:
# (1, 18)

# %%
#Use the thresh parameter in dropna() to keep only rows where a number of valid values is available.

# %%
#If all values are NA, drop that row
ebola_drop=ebola.dropna(how='all')   #to drope whole row as a null value
ebola_drop.shape

#but 0 rows were dropped, meaning that every single row has value there since retained 122 rows
# Out:
# (122, 18)

# %%
#put a THRESHOLD to keep the rows with 1 valid values
ebola_drop=ebola.dropna(thresh=1)  
ebola_drop.shape
# Out:
# (122, 18)

# %%
#put a THRESHOLD to keep the rows with 4 valid values
ebola_drop=ebola.dropna(thresh=4)  
ebola_drop.shape
# Out:
# (120, 18)
